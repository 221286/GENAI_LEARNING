# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel,Field
from typing import List
load_dotenv()
# Out:
# True

# %%
llm=ChatGroq(model="llama-3.3-70b-versatile")
class movieStructure (BaseModel):
    movieName:str=Field(description="this is the movie name")
    releaseDate:str=Field(description="This is the movie name")

class movieList (BaseModel):
   movies: List[movieStructure]


structuredllm=llm.with_structured_output(movieList)
response=structuredllm.invoke("I want 5 movies along with the release date")
response
# Out:
# movieList(movies=[movieStructure(movieName='Inception', releaseDate='2010-07-16'), movieStructure(movieName='The Shawshank Redemption', releaseDate='1994-09-23'), movieStructure(movieName='The Dark Knight', releaseDate='2008-07-18'), movieStructure(movieName='12 Angry Men', releaseDate='1957-04-10'), movieStructure(movieName="Schindler's List", releaseDate='1993-12-15')])
