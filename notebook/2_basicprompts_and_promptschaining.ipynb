# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import HumanMessage,SystemMessage
from langchain_core.output_parsers import StrOutputParser


load_dotenv()
# Out:
# True

# %%
prompts=[("system", "Think like a UPSC aspirant"),
    ("human", "Who is the first Prime Minister of India?")]
llm=ChatGroq(model="llama-3.3-70b-versatile")
response=llm.invoke(prompts)
response.content
# Out:
# "The first Prime Minister of India was Jawaharlal Nehru. He served as the Prime Minister from August 15, 1947, to May 27, 1964, and played a crucial role in shaping the country's early years after independence. \n\nAs a UPSC aspirant, it's essential to remember that Nehru was not only the first Prime Minister but also a key figure in the Indian independence movement, and his tenure saw the implementation of various significant policies, including the establishment of the Planning Commission, the introduction of the Five-Year Plans, and the promotion of socialism and secularism. \n\nIt's also worth noting that Nehru's leadership style, foreign policy, and domestic initiatives have been subject to both praise and criticism, and as a UPSC aspirant, you should be prepared to analyze and evaluate his tenure in the context of Indian history and politics."

# %%
content=StrOutputParser()

# %%
def transformToUpperCase(result:str):
    return result.upper()

# %%
prompts=ChatPromptTemplate.from_messages([
    ("system", "Translate my text into {language}.Do not answer the question just translate"),
    ("human", "{contents}")
])
prompts
# Out:
# ChatPromptTemplate(input_variables=['contents', 'language'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='Translate my text into {language}.Do not answer the question just translate'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['contents'], input_types={}, partial_variables={}, template='{contents}'), additional_kwargs={})])

# %%
# final_prompts=prompts.format_messages(language="Hindi",contents="How are you?")
# from langchain_groq import ChatGroq
# llm=ChatGroq(model="llama-3.3-70b-versatile") 
# response=llm.invoke(final_prompts)
# response.content

# %%
from langchain_core.prompts import ChatPromptTemplate
practicePrompt=ChatPromptTemplate.from_messages([("system","Transtale to {languu}"),("human","{contents}")])
# practicePrompt.invoke({"languu":"Hindi","contents":"I am a good boy"})
# practicePrompt
# response=llm.invoke(practicePrompt.invoke({"languu":"Hindi","contents":"I am a good boy"}))
# response.content

# %%
chains= practicePrompt | llm | content | transformToUpperCase
response=chains.invoke({"languu":"English","contents":"मैं एक अच्छा लड़का हूँ"})
print(response)
# Out:
# THE TRANSLATION OF "मैं एक अच्छा लड़का हूँ" TO ENGLISH IS:
#
# "I AM A GOOD BOY."
