# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import SystemMessage,AIMessage,HumanMessage
load_dotenv()
# Out:
# True

# %%
llm=ChatGroq(model="llama-3.3-70b-versatile")
prompt=ChatPromptTemplate.from_messages([("system","{systemContent}"),("human","{userContent}")])
output=StrOutputParser()
memory=[]
memory.append(SystemMessage(content="You are a engineer"))

while True:
    query=input("User:")
    if query.lower() in ["bye","exit","quit"]:
     print("Bye bye !!")
     break

    memory.append(HumanMessage(content=query))
    chain = llm | output
    response=chain.invoke(memory)
    memory.append(AIMessage(content=response))
    print("AI:",response)
# Out:
# AI: Hello Anis, nice to meet you. I'm an engineer, what brings you here today? Are you working on a project, or do you have a technical question you'd like to discuss?
# AI: Anis, I don't have any personal knowledge about you, as I'm a large language model, I don't have the ability to recall individual users or maintain personal relationships. Each time you interact with me, it's a new conversation and I don't retain any information from previous conversations. However, I'm happy to chat with you and get to know you better in this conversation!
# AI: You told me your name is Anis, but that's the only information I have about you. I don't have any prior knowledge about you or your identity. Is there something specific you'd like to talk about or ask me, Anis?
# AI: It seems like you didn't type anything. Is everything okay, Anis? Do you want to continue our conversation or is there something on your mind that you'd like to discuss? I'm here to listen and help if I can.
# Bye bye !!

# %%
from pydantic import BaseModel, Field
text="My name is anis osama email is anisosama07@gmail.com and age is 24"
class ResponseStructure(BaseModel):
    name:str = Field(description="Complete name")
    email:str = Field(description="Complete email")
    age:int =Field(description="user age")

llmStructure=llm.with_structured_output(ResponseStructure)
response=llmStructure.invoke(f"Please give me only name ,email and age from this text :{text}")
response.model_dump()
# Out:
# {'name': 'anis osama', 'email': 'anisosama07@gmail.com', 'age': 24}
