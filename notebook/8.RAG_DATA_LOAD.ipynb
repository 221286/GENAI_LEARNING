# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("../data/speech.txt")
text=loader.load()
len()
# Out:
# 1

# %%
from langchain_community.document_loaders import PyPDFLoader
loader =PyPDFLoader("../data/medical_report.pdf")
text=loader.load()
print(text[0])
# Out:
# page_content='Report Status
# Female
# 27 Years:
# :
# :
# :
# Age
# Gender
# Reported
# P
# 9/7/2025   4:56:00PM
# DR NITIN NAHAR
# 474764803
# Ms. NIKITA  CHUDHARY:
# :
# :
# :
# :
# Name
# Lab No.
# Ref By
# Collected
# A/c Status
# 10/7/2025  6:31:50PM
# Final
# Collected at            : Processed at             :BHOPAL CC-82
# Mr Rachel V John Pata So Vitus John Mig 26
# Graund,Indrapuri, Phone: 8770817968
#
# LPL - Bhopal Lab II
# Plot No.05, Mandakini Housing Society, Near
# Apurti Shopping Mall, Kolar Main Road,
# Bhopal, M.P. -  462042
# Test Report
# Test Name Results Units Bio. Ref. Interval
# HEMOGRAM
# (SLS Method, Sheath Flow DC Detection Method, Fluorescent Flow Cytometry, Calculated & Capillary Photometry)
# Hemoglobin  12.00 - 15.00 g/dL13.10
# Packed Cell Volume (PCV)  36.00 - 46.00 %39.50
# RBC Count  3.80 - 4.80 mill/mm34.47
# MCV  83.00 - 101.00 fL88.40
# Mentzer Index   19.8
# MCH  27.00 - 32.00 pg29.30
# MCHC  31.50 - 34.50 g/dL33.20
# ...

# %%
from langchain_community.document_loaders import CSVLoader
loader=CSVLoader("../data/employee_records.csv")
text=loader.load()
print(text[0])
# Out:
# page_content='Employee_ID: 1
# Employee_Name: Daniel Taylor
# Age: 25
# Country: UK
# Department: HR
# Position: Analyst
# Salary: 142278.32
# Joining_Date: 2023-06-04' metadata={'source': '../data/employee_records.csv', 'row': 0}

# %%
from langchain_community.document_loaders import WebBaseLoader
loader=WebBaseLoader(web_path="https://jobs.citi.com/job/pune/java-fullstack-developer-c11-pune/287/78060291184")
docs=loader.load()
print(docs[0].metadata["description"])
# Out:
# Learn more about applying for Java Fullstack Developer - C11 - Pune at Citi. Learn more about potential responsibilities, qualifications and career paths.

# %%
from langchain_community.document_loaders import WikipediaLoader
loader=WikipediaLoader(query="Python (programming language)", load_max_docs=2)
text=loader.load()
print(text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Documents/GEN_AI_SERIES/env/lib/python3.9/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# ...
